# %% [markdown]
# Let's make a recap about Marks, Channels and the GRammar of Graphics.

# %% [markdown]
# ### Marks

# %% [markdown]
# **Marks are basic geometric elements that depict items**
#
# Marks are geometric primitives classified according to the number of dimensions they require.
#
# Examples: points (0D), lines (1D), areas (2D) and volumes (3D).
#
# ▪ Volume marks are not commonly used.
#
# *Tamara Muzner. Visualization Analysis and Design*

# %% [markdown]
# ![marks](../img/marks.png)

# %% [markdown]
# ## Channels

# %% [markdown]
# **A visual channel is a way to control the appearance of marks, independent of the dimensionality of the geometric primitives.**
#
# *Tamara Muzner. Visualization Analysis and Design*

# %% [markdown]
# There are some commonly seen channel types:
# - position
# - color
# - shape
# - size

# %% [markdown]
# ![channels](../img/channels.png)

# %% [markdown]
# ## Grammar or Graphics

# %% [markdown]
# **"Applied to visualizations, a grammar of graphics is a grammar used to describe and create a wide range of statistical graphics."**
#
# *Wilkinson, Leland. (2005). The Grammar of Graphics.*

# %% [markdown]
# The components of the Layered Grammar of Graphs are:
#
# - Layer
#     - Data
#     - Mapping
#     - Statistical transformation (stat)
#     - **Geometric object (geom)**
#     - **Position adjustment (position)**
# - Scale
# - Coordinate system (coord)
# - Faceting (facet)

# %% [markdown]
# ## Presenting GGplot2

# %% [markdown]
# ggplot2 is a system for declaratively creating graphics, based on The Grammar of Graphics. You provide the data, tell ggplot2 how to map variables to aesthetics, what graphical primitives to use, and it takes care of the details.
#
# It is part of the tidyverse
#
# https://ggplot2.tidyverse.org/

# %% [markdown]
# Cheatsheet can be found here:
# https://github.com/rstudio/cheatsheets/blob/main/data-visualization.pdf

# %% [markdown]
# The basic steps to build a graphic are:
#  - Have data in a dataframe
#  - Open the canvas
#  - Map **channels** to variables in dataframe
#  - Pick a primitive (**mark**)
#
# Let's create a simple plot.

# %%
library(readr)
library(magrittr)
library(dplyr)
library(tidyr)
library(ggplot2)

# %%
df <- read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv', show_col_types = FALSE)
head(df)
# Out:
#   iso_code continent location    date       total_cases new_cases
# 1 AFG      Asia      Afghanistan 2020-02-24 5           5
# 2 AFG      Asia      Afghanistan 2020-02-25 5           0
# 3 AFG      Asia      Afghanistan 2020-02-26 5           0
# 4 AFG      Asia      Afghanistan 2020-02-27 5           0
# 5 AFG      Asia      Afghanistan 2020-02-28 5           0
# 6 AFG      Asia      Afghanistan 2020-02-29 5           0
#   new_cases_smoothed total_deaths new_deaths new_deaths_smoothed ⋯ male_smokers
# 1    NA              NA           NA         NA                  ⋯ NA
# 2    NA              NA           NA         NA                  ⋯ NA
# 3    NA              NA           NA         NA                  ⋯ NA
# 4    NA              NA           NA         NA                  ⋯ NA
# 5    NA              NA           NA         NA                  ⋯ NA
# 6 0.714              NA           NA         NA                  ⋯ NA
#   handwashing_facilities hospital_beds_per_thousand life_expectancy
# 1 37.746                 0.5                        64.83
# 2 37.746                 0.5                        64.83
# 3 37.746                 0.5                        64.83
# 4 37.746                 0.5                        64.83
# 5 37.746                 0.5                        64.83
# 6 37.746                 0.5                        64.83
#   human_development_index population excess_mortality_cumulative_absolute
# 1 0.511                   41128772   NA
# 2 0.511                   41128772   NA
# 3 0.511                   41128772   NA
# 4 0.511                   41128772   NA
# 5 0.511                   41128772   NA
# 6 0.511                   41128772   NA
#   excess_mortality_cumulative excess_mortality
# 1 NA                          NA
# 2 NA                          NA
# 3 NA                          NA
# 4 NA                          NA
# 5 NA                          NA
# 6 NA                          NA
#   excess_mortality_cumulative_per_million
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
# here he have the dataframe
df %>%
  filter ( location == 'Mexico',
           date >= '2022-07-01')  %>%
  head()
# Out:
#   iso_code continent     location date       total_cases new_cases
# 1 MEX      North America Mexico   2022-07-01 6058689     24087
# 2 MEX      North America Mexico   2022-07-02 6058689         0
# 3 MEX      North America Mexico   2022-07-03 6089600     30911
# 4 MEX      North America Mexico   2022-07-04 6093835      4235
# 5 MEX      North America Mexico   2022-07-05 6121808     27973
# 6 MEX      North America Mexico   2022-07-06 6152924     31116
#   new_cases_smoothed total_deaths new_deaths new_deaths_smoothed ⋯ male_smokers
# 1 19371.86           325747       31         33.714              ⋯ 21.4
# 2 14565.29           325747        0         24.429              ⋯ 21.4
# 3 18140.71           325788       41         29.714              ⋯ 21.4
# 4 18268.14           325793        5         28.143              ⋯ 21.4
# 5 19270.14           325868       75         32.857              ⋯ 21.4
# 6 23715.29           325928       60         41.429              ⋯ 21.4
#   handwashing_facilities hospital_beds_per_thousand life_expectancy
# 1 87.847                 1.38                       75.05
# 2 87.847                 1.38                       75.05
# 3 87.847                 1.38                       75.05
# 4 87.847                 1.38                       75.05
# 5 87.847                 1.38                       75.05
# 6 87.847                 1.38                       75.05
#   human_development_index population excess_mortality_cumulative_absolute
# 1 0.779                   127504120        NA
# 2 0.779                   127504120        NA
# 3 0.779                   127504120  654743.9
# 4 0.779                   127504120        NA
# 5 0.779                   127504120        NA
# 6 0.779                   127504120        NA
#   excess_mortality_cumulative excess_mortality
# 1    NA                          NA
# 2    NA                          NA
# 3 33.55                       -4.13
# 4    NA                          NA
# 5    NA                          NA
# 6    NA                          NA
#   excess_mortality_cumulative_per_million
# 1       NA
# 2       NA
# 3 5167.461
# 4       NA
# 5       NA
# 6       NA

# %% [markdown]
# To map variables to the channels, we use the function `aes()`.
# This can be used:
#  - In the `ggplot` command (this inherits the aesthetics to the marks)
#  - In the `geom_()` command (only apply the aesthetics to this mark)

# %%
# assign channels in ggplot command
df %>%
  filter ( location == 'Mexico',
           date >= '2022-07-01')  %>%
  ggplot(aes(
      x = date,
      y = new_cases
  ))
# Out:
# plot without title

# %%
# assign channels in ggplot command
df %>%
  filter ( location == 'Mexico',
           date >= '2022-10-01')  %>%
  ggplot(aes(
      x = date,
      y = new_cases
  )) +
  geom_bar(stat = "identity")
# Out:
# plot without title

# %%
# assign channels in the geom command
df %>%
  filter ( location == 'Mexico',
           date >= '2022-10-01')  %>%
  ggplot() +
  geom_bar(aes(
      x = date,
      y = new_cases
  ),
  stat = "identity")
# Out:
# plot without title

# %% [markdown]
# One of the beauties of ggplot is that is very easy to modify the labels, colors, legends, etc.
#
# Even, there are basic templates we can use out of the box

# %%
df %>%
  filter ( location == 'Mexico',
           date >= '2022-10-01')  %>%
  ggplot() +
  geom_bar(aes(
      x = date,
      y = new_cases
  ),
  stat = "identity") +
  theme_minimal()
# Out:
# plot without title

# %%
df %>%
  filter ( location == 'Mexico',
           date >= '2022-10-01')  %>%
  ggplot() +
  geom_bar(aes(
      x = date,
      y = new_cases
  ),
  stat = "identity") +
  theme_gray()
# Out:
# plot without title

# %%
df %>%
  filter ( location == 'Mexico',
           date >= '2022-10-01')  %>%
  ggplot() +
  geom_bar(aes(
      x = date,
      y = new_cases
  ),
  stat = "identity") +
  theme_classic()
# Out:
# plot without title

# %% [markdown]
# ### Why the aes() is important

# %% [markdown]
# Let's assign a colors to the fill of each bar. First we will do outside the `aes()` and after, inside of.

# %%
df %>%
  filter ( location == 'Mexico',
           date >= '2022-10-01')  %>%
  ggplot() +
  geom_bar(aes(
      x = date,
      y = new_cases
  ),
  fill = '#33A1FD',
  stat = "identity") +
  theme_classic()
# Out:
# plot without title

# %%
df %>%
  filter ( location == 'Mexico',
           date >= '2022-10-01')  %>%
  ggplot() +
  geom_bar(aes(
      x = date,
      y = new_cases,
      fill = '#33A1FD',
  ),
  stat = "identity") +
  theme_classic()
# Out:
# plot without title

# %% [markdown]
# Why happened this?
#
# Because if we assign the fill color inside the `aes()`, ggplot expects a variable. Tha means, that we use the `aes()` to encode variables, **not constants**.

# %%
# assign fill to the number of new cases
df %>%
  filter ( location == 'Mexico',
           date >= '2022-10-01')  %>%
  ggplot() +
  geom_bar(aes(
      x = date,
      y = new_cases,
      fill = new_cases,
  ),
  stat = "identity") +
  theme_classic()
# Out:
# plot without title

# %% [markdown]
# ### Line Plot

# %%
# assign fill to the number of new cases
df %>%
  filter ( location == 'Mexico',
           date >= '2022-10-01')  %>%
  ggplot() +
  geom_line(aes(
      x = date,
      y = new_cases
  ),
     color = '#33A1FD') +
  theme_classic()
# Out:
# plot without title

# %% [markdown]
# ### Scatterplot

# %% [markdown]
# For scatterplot leasia_data = data.query('continent == "Asia" and date == "2022-07-01"')t's create the same dataframe we used in Python notebook

# %%
asia_df <- df %>%
  filter ( continent == 'Asia',
           date == '2022-07-01')

head(asia_df)
# Out:
#   iso_code continent location    date       total_cases new_cases
# 1 AFG      Asia      Afghanistan 2022-07-01  182594       66
# 2 ARM      Asia      Armenia     2022-07-01  423243        0
# 3 AZE      Asia      Azerbaijan  2022-07-01  793302      126
# 4 BHR      Asia      Bahrain     2022-07-01  627327     1471
# 5 BGD      Asia      Bangladesh  2022-07-01 1975682     1893
# 6 BTN      Asia      Bhutan      2022-07-01   59729        0
#   new_cases_smoothed total_deaths new_deaths new_deaths_smoothed ⋯ male_smokers
# 1   80.143            7723        0          0.857               ⋯   NA
# 2   19.857            8629        0          0.000               ⋯ 52.1
# 3   28.000            9717        0          0.000               ⋯ 42.5
# 4 1743.143            1493        1          0.143               ⋯ 37.6
# 5 1924.143           29154        5          2.714               ⋯ 44.7
# 6    7.857              21        0          0.000               ⋯   NA
#   handwashing_facilities hospital_beds_per_thousand life_expectancy
# 1 37.746                 0.5                        64.83
# 2 94.043                 4.2                        75.09
# 3 83.241                 4.7                        73.00
# 4     NA                 2.0                        77.29
# 5 34.808                 0.8                        72.59
# 6 79.807                 1.7                        71.78
#   human_development_index population excess_mortality_cumulative_absolute
# 1 0.511                    41128772  NA
# 2 0.776                     2780472  NA
# 3 0.756                    10358078  NA
# 4 0.852                     1472237  NA
# 5 0.632                   171186368  NA
# 6 0.654                      782457  NA
#   excess_mortality_cumulative excess_mortality
# 1 NA                          NA
# 2 NA                          NA
# 3 NA                          NA
# 4 NA                          NA
# 5 NA                          NA
# 6 NA                          NA
#   excess_mortality_cumulative_per_million
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
asia_df %>% 
  ggplot() +
  geom_point(aes(
      x = handwashing_facilities,
      y = life_expectancy
  ),
     color = '#33A1FD') +
  labs(title = "Correlation betweeen handwashing facilities and life expectancy",
       caption = "Graphic made by PabloQ with data from https://covid.ourworldindata.org") +
  theme_classic()
# Out:
# Warning message:
# “Removed 24 rows containing missing values (geom_point).”
# plot without title

# %%
asia_df %>% 
  ggplot(aes(
      x = handwashing_facilities,
      y = life_expectancy,
      color = location
  )) +
  geom_point() +
  labs(title = "Correlation betweeen handwashing facilities and life expectancy",
       caption = "Graphic made by PabloQ with data from https://covid.ourworldindata.org") +
  theme_classic()
# Out:
# Warning message:
# “Removed 24 rows containing missing values (geom_point).”
# plot without title

# %%
asia_df %>% 
  ggplot(aes(
      x = handwashing_facilities,
      y = life_expectancy,       
      color =  ifelse(handwashing_facilities > 80, "#FF5577", "#BCC5C8")
  )) +
  geom_point() +
  geom_label(aes(label = location)) +
  scale_color_identity() +
  labs(title = "Correlation betweeen handwashing facilities and life expectancy",
       caption = "Graphic made by PabloQ with data from https://covid.ourworldindata.org") +
  theme_classic()
# Out:
# Warning message:
# “Removed 24 rows containing missing values (geom_point).”
# Warning message:
# “Removed 24 rows containing missing values (geom_label).”
# plot without title

# %% [markdown]
# ### Heatmap

# %%
asia_df <- df %>%
  filter ( continent == 'Asia',
           date >= '2022-10-01',
           total_deaths > 30000)

# %%
asia_df %>% 
  ggplot(aes(
      x = location,
      y = date,       
      fill = new_cases
  )) +
  geom_tile() +
  labs(title = "Heatmap graphic",
       caption = "Graphic made by PabloQ with data from https://covid.ourworldindata.org") +
  theme_classic()
# Out:
# plot without title
